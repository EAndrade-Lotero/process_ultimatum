# %% [markdown]
# # Data preprocessing

# %%
import sys
sys.path.append('..')

import warnings
warnings.filterwarnings('ignore')

import ast
import json
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from config import PATHS
from pre_processing_utils import Utils

# %%
experiment_paths = [
    # PATHS['human_data'], 
    # PATHS['human_data1'], 
    PATHS['human_data2'],
    PATHS['human_data3'],
]
data = Utils.preprocess_dataframes(experiment_paths)
data.to_csv(PATHS['processed_data'] / 'data.csv', index=False)
# Out:
# ...
# Processing experiment 1...
# ...

# %%
data.head(2)
# Out:
#    session   power_role  power_forager_id  starting_overhead   map  \
# 0        1  coordinator               NaN               0.05  map3
# 1        1      forager               1.0               0.50  map2
#
#    network_id  time_step  node_id  given_overhead  participant_id  complete  \
# 0          13          1       13            0.05               4      True
# 1          10          1       10            0.50               1      True
#
#           role  investment  forager_id  my_coins  all_coins_simulated  \
# 0  coordinator         0.5         NaN       NaN                 60.0
# 1  coordinator         0.2         NaN       NaN                 38.0
#
#    all_coins_real  score  proposed_overhead  normalized_score
# 0            52.0    8.0               0.07          0.081633
# 1             0.0   27.0               0.65          0.275510
